# %%
import random
import pandas
import matplotlib.pyplot as plt
import numpy as np
import cyclic_code_functions

# %%
cyclic_code_functions.probability_error(1011, 6, 0.05)

# %%
cyclic_code_functions.probability_error(1011, 6, 0.01)
